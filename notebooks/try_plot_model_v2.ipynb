# %%
from neural_network import ChessNN
import tensorflow as tf
from tensorflow.keras.utils import plot_model

# %%
nn = ChessNN()
model = nn.build_model()
# Out:
# 2025-12-07 15:02:31.032925: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2025-12-07 15:02:31.033018: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-12-07 15:02:31.033040: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-12-07 15:02:31.033271: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-12-07 15:02:31.033755: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "chess_nn"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  board_input (InputLayer)    [(None, 8, 8, 18)]           0         []
#
#  initial_conv (Conv2D)       (None, 8, 8, 128)            20736     ['board_input[0][0]']
#
#  initial_bn (BatchNormaliza  (None, 8, 8, 128)            512       ['initial_conv[0][0]']
#  tion)
#
#  initial_relu (ReLU)         (None, 8, 8, 128)            0         ['initial_bn[0][0]']
#
#  res_1_conv1 (Conv2D)        (None, 8, 8, 128)            147456    ['initial_relu[0][0]']
#
#  res_1_bn1 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_1_conv1[0][0]']
#  ion)
#
#  res_1_relu1 (ReLU)          (None, 8, 8, 128)            0         ['res_1_bn1[0][0]']
#
#  res_1_conv2 (Conv2D)        (None, 8, 8, 128)            147456    ['res_1_relu1[0][0]']
#
#  res_1_bn2 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_1_conv2[0][0]']
#  ion)
#
#  res_1_add (Add)             (None, 8, 8, 128)            0         ['res_1_bn2[0][0]',
#                                                                      'initial_relu[0][0]']
#
#  res_1_relu2 (ReLU)          (None, 8, 8, 128)            0         ['res_1_add[0][0]']
#
#  res_2_conv1 (Conv2D)        (None, 8, 8, 128)            147456    ['res_1_relu2[0][0]']
#
#  res_2_bn1 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_2_conv1[0][0]']
#  ion)
#
#  res_2_relu1 (ReLU)          (None, 8, 8, 128)            0         ['res_2_bn1[0][0]']
#
#  res_2_conv2 (Conv2D)        (None, 8, 8, 128)            147456    ['res_2_relu1[0][0]']
#
#  res_2_bn2 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_2_conv2[0][0]']
#  ion)
#
#  res_2_add (Add)             (None, 8, 8, 128)            0         ['res_2_bn2[0][0]',
#                                                                      'res_1_relu2[0][0]']
#
#  res_2_relu2 (ReLU)          (None, 8, 8, 128)            0         ['res_2_add[0][0]']
#
#  res_3_conv1 (Conv2D)        (None, 8, 8, 128)            147456    ['res_2_relu2[0][0]']
#
#  res_3_bn1 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_3_conv1[0][0]']
#  ion)
#
#  res_3_relu1 (ReLU)          (None, 8, 8, 128)            0         ['res_3_bn1[0][0]']
#
#  res_3_conv2 (Conv2D)        (None, 8, 8, 128)            147456    ['res_3_relu1[0][0]']
#
#  res_3_bn2 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_3_conv2[0][0]']
#  ion)
#
#  res_3_add (Add)             (None, 8, 8, 128)            0         ['res_3_bn2[0][0]',
#                                                                      'res_2_relu2[0][0]']
#
#  res_3_relu2 (ReLU)          (None, 8, 8, 128)            0         ['res_3_add[0][0]']
#
#  res_4_conv1 (Conv2D)        (None, 8, 8, 128)            147456    ['res_3_relu2[0][0]']
#
#  res_4_bn1 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_4_conv1[0][0]']
#  ion)
#
#  res_4_relu1 (ReLU)          (None, 8, 8, 128)            0         ['res_4_bn1[0][0]']
#
#  res_4_conv2 (Conv2D)        (None, 8, 8, 128)            147456    ['res_4_relu1[0][0]']
#
#  res_4_bn2 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_4_conv2[0][0]']
#  ion)
#
#  res_4_add (Add)             (None, 8, 8, 128)            0         ['res_4_bn2[0][0]',
#                                                                      'res_3_relu2[0][0]']
#
#  res_4_relu2 (ReLU)          (None, 8, 8, 128)            0         ['res_4_add[0][0]']
#
#  res_5_conv1 (Conv2D)        (None, 8, 8, 128)            147456    ['res_4_relu2[0][0]']
#
#  res_5_bn1 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_5_conv1[0][0]']
#  ion)
#
#  res_5_relu1 (ReLU)          (None, 8, 8, 128)            0         ['res_5_bn1[0][0]']
#
#  res_5_conv2 (Conv2D)        (None, 8, 8, 128)            147456    ['res_5_relu1[0][0]']
#
#  res_5_bn2 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_5_conv2[0][0]']
#  ion)
#
#  res_5_add (Add)             (None, 8, 8, 128)            0         ['res_5_bn2[0][0]',
#                                                                      'res_4_relu2[0][0]']
#
#  res_5_relu2 (ReLU)          (None, 8, 8, 128)            0         ['res_5_add[0][0]']
#
#  res_6_conv1 (Conv2D)        (None, 8, 8, 128)            147456    ['res_5_relu2[0][0]']
#
#  res_6_bn1 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_6_conv1[0][0]']
#  ion)
#
#  res_6_relu1 (ReLU)          (None, 8, 8, 128)            0         ['res_6_bn1[0][0]']
#
#  res_6_conv2 (Conv2D)        (None, 8, 8, 128)            147456    ['res_6_relu1[0][0]']
#
#  res_6_bn2 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_6_conv2[0][0]']
#  ion)
#
#  res_6_add (Add)             (None, 8, 8, 128)            0         ['res_6_bn2[0][0]',
#                                                                      'res_5_relu2[0][0]']
#
#  res_6_relu2 (ReLU)          (None, 8, 8, 128)            0         ['res_6_add[0][0]']
#
#  res_7_conv1 (Conv2D)        (None, 8, 8, 128)            147456    ['res_6_relu2[0][0]']
#
#  res_7_bn1 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_7_conv1[0][0]']
#  ion)
#
#  res_7_relu1 (ReLU)          (None, 8, 8, 128)            0         ['res_7_bn1[0][0]']
#
#  res_7_conv2 (Conv2D)        (None, 8, 8, 128)            147456    ['res_7_relu1[0][0]']
#
#  res_7_bn2 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_7_conv2[0][0]']
#  ion)
#
#  res_7_add (Add)             (None, 8, 8, 128)            0         ['res_7_bn2[0][0]',
#                                                                      'res_6_relu2[0][0]']
#
#  res_7_relu2 (ReLU)          (None, 8, 8, 128)            0         ['res_7_add[0][0]']
#
#  res_8_conv1 (Conv2D)        (None, 8, 8, 128)            147456    ['res_7_relu2[0][0]']
#
#  res_8_bn1 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_8_conv1[0][0]']
#  ion)
#
#  res_8_relu1 (ReLU)          (None, 8, 8, 128)            0         ['res_8_bn1[0][0]']
#
#  res_8_conv2 (Conv2D)        (None, 8, 8, 128)            147456    ['res_8_relu1[0][0]']
#
#  res_8_bn2 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_8_conv2[0][0]']
#  ion)
#
#  res_8_add (Add)             (None, 8, 8, 128)            0         ['res_8_bn2[0][0]',
#                                                                      'res_7_relu2[0][0]']
#
#  res_8_relu2 (ReLU)          (None, 8, 8, 128)            0         ['res_8_add[0][0]']
#
#  res_9_conv1 (Conv2D)        (None, 8, 8, 128)            147456    ['res_8_relu2[0][0]']
#
#  res_9_bn1 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_9_conv1[0][0]']
#  ion)
#
#  res_9_relu1 (ReLU)          (None, 8, 8, 128)            0         ['res_9_bn1[0][0]']
#
#  res_9_conv2 (Conv2D)        (None, 8, 8, 128)            147456    ['res_9_relu1[0][0]']
#
#  res_9_bn2 (BatchNormalizat  (None, 8, 8, 128)            512       ['res_9_conv2[0][0]']
#  ion)
#
#  res_9_add (Add)             (None, 8, 8, 128)            0         ['res_9_bn2[0][0]',
#                                                                      'res_8_relu2[0][0]']
#
#  res_9_relu2 (ReLU)          (None, 8, 8, 128)            0         ['res_9_add[0][0]']
#
#  res_10_conv1 (Conv2D)       (None, 8, 8, 128)            147456    ['res_9_relu2[0][0]']
#
#  res_10_bn1 (BatchNormaliza  (None, 8, 8, 128)            512       ['res_10_conv1[0][0]']
#  tion)
#
#  res_10_relu1 (ReLU)         (None, 8, 8, 128)            0         ['res_10_bn1[0][0]']
#
#  res_10_conv2 (Conv2D)       (None, 8, 8, 128)            147456    ['res_10_relu1[0][0]']
#
#  res_10_bn2 (BatchNormaliza  (None, 8, 8, 128)            512       ['res_10_conv2[0][0]']
#  tion)
#
#  res_10_add (Add)            (None, 8, 8, 128)            0         ['res_10_bn2[0][0]',
#                                                                      'res_9_relu2[0][0]']
#
#  res_10_relu2 (ReLU)         (None, 8, 8, 128)            0         ['res_10_add[0][0]']
#
#  value_conv (Conv2D)         (None, 8, 8, 1)              128       ['res_10_relu2[0][0]']
#
#  value_bn (BatchNormalizati  (None, 8, 8, 1)              4         ['value_conv[0][0]']
#  on)
#
#  policy_conv (Conv2D)        (None, 8, 8, 2)              256       ['res_10_relu2[0][0]']
#
#  value_relu1 (ReLU)          (None, 8, 8, 1)              0         ['value_bn[0][0]']
#
#  policy_bn (BatchNormalizat  (None, 8, 8, 2)              8         ['policy_conv[0][0]']
#  ion)
#
#  value_flatten (Flatten)     (None, 64)                   0         ['value_relu1[0][0]']
#
#  policy_relu (ReLU)          (None, 8, 8, 2)              0         ['policy_bn[0][0]']
#
#  value_dense1 (Dense)        (None, 256)                  16640     ['value_flatten[0][0]']
#
#  policy_flatten (Flatten)    (None, 128)                  0         ['policy_relu[0][0]']
#
#  value_relu2 (ReLU)          (None, 256)                  0         ['value_dense1[0][0]']
#
#  policy_dense (Dense)        (None, 4672)                 602688    ['policy_flatten[0][0]']
#
#  value_dense2 (Dense)        (None, 1)                    257       ['value_relu2[0][0]']
#
#  policy_output (Softmax)     (None, 4672)                 0         ['policy_dense[0][0]']
#
#  value_output (Activation)   (None, 1)                    0         ['value_dense2[0][0]']
#
# ==================================================================================================
# Total params: 3600589 (13.74 MB)
# Trainable params: 3595207 (13.71 MB)
# Non-trainable params: 5382 (21.02 KB)
# __________________________________________________________________________________________________

# %%
plot_model(
    model,
    to_file="model_architecture.png",
    show_shapes=True,
    show_layer_names=True,
    expand_nested=True,
    dpi=150
)
